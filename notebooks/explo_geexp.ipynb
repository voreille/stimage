# %%
import scanpy as sc
import pandas as pd
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adata = sc.read_h5ad("/workspaces/stimage/data/processed/gene_expression/pipeline_3_sctransform_harmony_human_lung_debug.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12244 × 18078
#     obs: 'image_id', 'spots_id', 'n_genes', 'initial_size', 'n_counts'
#     var: 'n_cells', 'gene_count_corr', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg', 'log1p', 'pca'
#     obsm: 'X_pca', 'X_pca_harmony'
#     varm: 'PCs'

# %%
x = adata.obsm['X_pca_harmony']

# %%
x.shape
# Out:
# (12244, 50)

# %%
explained_variance_ratio = adata.uns['pca']['variance_ratio']

# Print the explained variance for each component
for i, variance in enumerate(explained_variance_ratio):
    print(f"Principal Component {i+1}: {variance:.4f} variance explained")
# Out:
# Principal Component 1: 0.1991 variance explained
# Principal Component 2: 0.0790 variance explained
# Principal Component 3: 0.0501 variance explained
# Principal Component 4: 0.0420 variance explained
# Principal Component 5: 0.0231 variance explained
# Principal Component 6: 0.0152 variance explained
# Principal Component 7: 0.0113 variance explained
# Principal Component 8: 0.0071 variance explained
# Principal Component 9: 0.0067 variance explained
# Principal Component 10: 0.0056 variance explained
# Principal Component 11: 0.0048 variance explained
# Principal Component 12: 0.0045 variance explained
# Principal Component 13: 0.0038 variance explained
# Principal Component 14: 0.0035 variance explained
# Principal Component 15: 0.0034 variance explained
# Principal Component 16: 0.0029 variance explained
# Principal Component 17: 0.0023 variance explained
# Principal Component 18: 0.0019 variance explained
# Principal Component 19: 0.0018 variance explained
# ...

# %%
pca_1 = adata.obsm['X_pca_harmony'][:, 0]  # First principal component
pca_2 = adata.obsm['X_pca_harmony'][:, 1]  # Second principal component

image_ids = adata.obs['image_id']
# Create a DataFrame to hold the PCA components and image_id
df = pd.DataFrame({
    'PCA 1': pca_1,
    'PCA 2': pca_2,
    'image_id': image_ids
})

# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PCA 1', y='PCA 2', hue='image_id', palette='viridis')

# Add labels and title
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Gene Expression, Colored by Image ID')

# Show the plot
plt.show()

# %%
pca_1 = adata.obsm['X_pca'][:, 0]  # First principal component
pca_2 = adata.obsm['X_pca'][:, 1]  # Second principal component

image_ids = adata.obs['image_id']
# Create a DataFrame to hold the PCA components and image_id
df = pd.DataFrame({
    'PCA 1': pca_1,
    'PCA 2': pca_2,
    'image_id': image_ids
})

# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PCA 1', y='PCA 2', hue='image_id', palette='viridis')

# Add labels and title
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Gene Expression, Colored by Image ID')

# Show the plot
plt.show()
